# %%
from deepface import DeepFace
import  matplotlib.pyplot as plt
import pandas as pd

# %%
from deepface import DeepFace
img = "Downloads\deepface\IMG1.jpg"
img2= 'Downloads\deepface\img\IMG2.jpg'
img3 = 'Downloads\deepface\IMG1.jpg'

db = 'Downloads\deepface\img'

# %%
imgk= DeepFace.detectFace(img)
img3= DeepFace.detectFace(img2)
plt.imshow(img3)
# Out:
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.

# %%
plt.imshow(img3)

# %%
model_name ='Facenet'
resp = DeepFace.verify(img1_path= img,img2_path= img2,model_name= model_name)
resp
# Out:
# {'verified': True,
#  'distance': 0.2225194104503201,
#  'threshold': 0.4,
#  'model': 'Facenet',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 375, 'y': 605, 'w': 254, 'h': 254},
#   'img2': {'x': 524, 'y': 458, 'w': 207, 'h': 207}},
#  'time': 0.95}

# %%
model_name ='ArcFace'

resp = DeepFace.verify(img1_path= img,img2_path= img2,model_name= model_name)
resp
# Out:
# {'verified': True,
#  'distance': 0.3433722433879445,
#  'threshold': 0.68,
#  'model': 'ArcFace',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 375, 'y': 605, 'w': 254, 'h': 254},
#   'img2': {'x': 524, 'y': 458, 'w': 207, 'h': 207}},
#  'time': 1.21}

# %%
model_name ='VGG-Face'
resp = DeepFace.verify(img1_path= img,img2_path= img2,model_name= model_name)
resp
# Out:
# {'verified': True,
#  'distance': 0.1661474181687661,
#  'threshold': 0.4,
#  'model': 'VGG-Face',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 375, 'y': 605, 'w': 254, 'h': 254},
#   'img2': {'x': 524, 'y': 458, 'w': 207, 'h': 207}},
#  'time': 1.68}

# %%
model_name ='VGG-Face'
resp = DeepFace.verify(img1_path= img,img2_path= img2,model_name= model_name)
resp
# Out:
# {'verified': True,
#  'distance': 0.1661474181687661,
#  'threshold': 0.4,
#  'model': 'VGG-Face',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 375, 'y': 605, 'w': 254, 'h': 254},
#   'img2': {'x': 524, 'y': 458, 'w': 207, 'h': 207}},
#  'time': 1.88}

# %%
models = [
  "VGG-Face", 
  "Facenet", 
  "Facenet512", 
  "OpenFace", 
  "DeepFace", 
  "DeepID", 
  "ArcFace", 
  "Dlib", 
  "SFace",
]

#face verification
result = DeepFace.verify(img1_path = img, 
      img2_path = img2, 
      model_name = models[0]
)

#face recognition

#embeddings

# %%
model_name ='Facenet512'
resp = DeepFace.verify(img1_path= img,img2_path= img2,model_name= model_name)
resp
# Out:
# {'verified': True,
#  'distance': 0.25757188175325085,
#  'threshold': 0.3,
#  'model': 'Facenet512',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 375, 'y': 605, 'w': 254, 'h': 254},
#   'img2': {'x': 524, 'y': 458, 'w': 207, 'h': 207}},
#  'time': 1.13}

# %%
model_name ='Facenet'
resp = DeepFace.verify(img1_path= img,img2_path= img2,model_name= model_name,detector_backend= 'ssd')
resp
# Out:
# {'verified': True,
#  'distance': 0.15687888695220664,
#  'threshold': 0.4,
#  'model': 'Facenet',
#  'detector_backend': 'ssd',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 406, 'y': 586, 'w': 190, 'h': 271},
#   'img2': {'x': 544, 'y': 453, 'w': 156, 'h': 213}},
#  'time': 0.29}

# %%
df =DeepFace.find(img_path=img,db_path=db,model_name ='Facenet')
# Out:
# Finding representations: 100%|█████████████████████████████████████████████████████████| 30/30 [00:14<00:00,  2.08it/s]
# Representations stored in Downloads\deepface\img/representations_facenet.pkl file.Please delete this file when you add new identities in your database.
# find function lasts  14.620412111282349  seconds

# %%
df
# Out:
# [                                           identity  source_x  source_y  \
#  0                   Downloads\deepface\img/IMG1.jpg       375       605
#  1                   Downloads\deepface\img/IMG3.jpg       375       605
#  2  Downloads\deepface\img/IMG_20230318_124811~2.jpg       375       605
#  3  Downloads\deepface\img/IMG_20230318_124632~2.jpg       375       605
#  4    Downloads\deepface\img/IMG_20230318_124632.jpg       375       605
#  5                   Downloads\deepface\img/IMG2.jpg       375       605
#  6        Downloads\deepface\img/20230325_192704.jpg       375       605
#  7        Downloads\deepface\img/20230325_192723.jpg       375       605
#
#     source_w  source_h  Facenet_cosine
#  0       254       254    3.330669e-16
#  1       254       254    1.733749e-01
#  2       254       254    1.843399e-01
#  3       254       254    1.990874e-01
#  4       254       254    2.081038e-01
#  5       254       254    2.225194e-01
# ...

# %%
obj=DeepFace.analyze(img_path=img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00,  8.62it/s]

# %%
obj
# Out:
# [{'emotion': {'angry': 0.049616495286197035,
#    'disgust': 2.1200298987039934e-07,
#    'fear': 0.20816738098354567,
#    'happy': 0.01659445354101243,
#    'sad': 0.1393178311803542,
#    'surprise': 0.005748327063479587,
#    'neutral': 99.58055024378893},
#   'dominant_emotion': 'neutral',
#   'region': {'x': 375, 'y': 605, 'w': 254, 'h': 254},
#   'age': 26,
#   'gender': {'Woman': 0.017823392408899963, 'Man': 99.98218417167664},
#   'dominant_gender': 'Man',
#   'race': {'asian': 3.4711796790361404,
#    'indian': 71.10486030578613,
#    'black': 3.748892992734909,
#    'white': 3.1919941306114197,
#    'middle eastern': 2.9321834444999695,
#    'latino hispanic': 15.550893545150757},
#   'dominant_race': 'indian'}]
